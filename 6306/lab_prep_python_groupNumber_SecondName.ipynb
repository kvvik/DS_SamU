# %% [markdown]
# #  Лабораторная работа python
#
# Подготовительная лабораторная работа
#
# Знакомство с Python
#
# Выполнил: номер группы, фио (изменить имя файла)

# %% [markdown]
# - Установите python 3
# - Установите jupyter-notebook
# - Загрузите данный .ipynb файл себе на компьютер
# - Запустите jupyter и выполните задания ниже

# %% [markdown]
# **Рекомендация:** Выполняйте каждый пункт задания или даже каждую операцию в отдельной ячейке

# %% [markdown]
# **1 Приведите примеры основных типов данных Python**
#
# 1.1 примеры целочисленного типа
#
# 1.2 примеры вещественного
#
# 1.3 примеры строк

# %%
--0.5
# Out:
# 0.5

# %%
a = 5
print(a)
# Out:
# 5

# %% [markdown]
# **2. Приведите примеры основных математических операций над числовыми типами данных**
#
# 2.1 Сложение
#
# 2.2 Вычитание
#
# 2.3 Умножение
#
# 2.4 Возведение в степень
#
# 2.5 Деление
#
# 2.6 Целочисленное деление
#
# 2.7 Получение остатка от деления

# %% [markdown]
# **3. Выполните основные операции над строками**
#
# 3.1 Конкатенация строк
#
# 3.2 Репликация строки
#
# 3.3 Конкатенация строки и числа (тип результата операции - строка)
#
# `#Пример с ошибкой
# a = 'My python version is '
# b = 3.9
# print (a+b)`
#
#
# 3.4 Создайте строковую переменную и выведите ее длину

# %% [markdown]
# **4. Работа с типом данных List (список)**
#
# 4.1 Создайте список с числовыми данными одним способом и список строк другим способом
#
# 4.2 Выполните конкатенацию созданных списков и сохраните результат в новую переменную
#
# 4.3 Добавьте новый элемент в конец любого списка
#
# 4.4 Добавьте новый элемент в список с указанием индекса места вставки
#
# 4.5 Удалите элемент, равный заданному значению, из списка
#
# 4.6 Удалите последний элемент из списка
#
# 4.7 Удалите элемент по индексу
#
# 4.8 Создайте вложенный список (список, элементами котрого являются списки)
#
# 4.9 Создайте список из чисел и отсортируйте его по убыванию и по возрастанию, напечатайте результат
#
# 4.10 Выведите срез списка по индексам
#
# 4.11 Выведите элемент списка с заданным индексом
#
# 4.12 Замените элемент списка с заданным индексом
#
# 4.13 Создайте копию списка и сохраните ее в новую переменную
#
# 4.14 Используя цикл for выполните любую операцию с каждым элементом списка. Обязательно прокомментируйте ваши действия.

# %% [markdown]
# **5. Работа с типом данных Tuple (кортеж)**
#
# 5.1 Создайте кортеж чисел, выведите его срез
#
# 5.2 Напишите, чем кортеж отличается от списка?
#
# 5.3 Используя приведение типа, создайте список из кортежа

# %% [markdown]
# **6. Работа с типом данных Dictionary (словарь)**
#
# 6.1 Создайте словарь, состоящий из нескольких элементов. В качестве ключа пусть будет номер лабораторной, а в качестве значений тема/название лабораторной.
#
# 6.2 Выведите keys, values и items словаря
#
# 6.3 Продемонстрируйте доступ по ключу. Например, выведите название второй лабораторной
#
# 6.4 Измените значение списка
#
# 6.5 Добавьте новый элемент (пару ключ/значение) в словарь

# %% [markdown]
# **6. Работа с типом данных Set (множество)**
#
# 6.1 Напишите различия множества, списка и кортежа
#
# 6.2 Создайте множество двумя способами
#
# 6.3 Создайте список, содержащий дубликаты элементов. Создайте множество из списка. Выведите созданные список и множество. Отличается ли содержимое множества от списка? Почему?
#
# 6.4 Создайте два множества, выведите их пересечение и объединение.

# %% [markdown]
# **7. Создание функций**
#
# 7.1 Объявите функции, вычисляющие сумму, среднее, максимальное и минимальное значение списка. Продемонстрируйте их работу.
#
# 7.2 Вычислить данные статистики с помощью встроеных в питон функций (найти в документации)

# %% [markdown]
# **8. Найдите и продемонстрируйте работу 15 встроенных функций питон, которые вы считаете полезными  и которые еще не использовались в данной работе. Прокомментируйте каждую.** Рекомендую изучить функции для  работы с файлами (модуль os https://pythonworld.ru/moduli/modul-os.html ,модуль os.path https://pythonworld.ru/moduli/modul-os-path.html) и функции для работы со строками (https://pythonworld.ru/tipy-dannyx-v-python/stroki-funkcii-i-metody-strok.html)

# %% [markdown]
# **9. Знакомство с ООП в Python. Создайте  класс c 2-3 свойствами и 2-3 методами. Продемонстрируйте работу с данным классом.**
#
# Полезные ссылки:
#
# - https://pythonchik.ru/osnovy/osnovy-oop-v-python-klassy-obekty-metody
#
# - https://habr.com/ru/post/455796/
